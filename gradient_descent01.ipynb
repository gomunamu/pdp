# %% [markdown]
# <a href="https://colab.research.google.com/github/gomunamu/pdp/blob/main/gradient_descent01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x: x**2 - 4*x +6
x = np.linspace(-1, 6, 100)
y = f(x)

plt.plot(x, y, 'k-')
plt.plot(2, 2, 'sk')
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %%
grad_f = lambda x: 2*x - 4
x0 = 0.0
MaxIter = 10
learning_rate = 0.25
print("step\tx\tf(x)")
print("{:02d}\t{:6.5f}\t{:6.5f}".format(0, x0, f(x0)))

for i in range(MaxIter):
  x1 = x0 - learning_rate * grad_f(x0)
  x0 = x1
  print("{:02d}\t{:6.5f}\t{:6.5f}".format(i+1, x0, f(x0)))
# Out:
# step	x	f(x)
# 00	0.00000	6.00000
# 01	1.00000	3.00000
# 02	1.50000	2.25000
# 03	1.75000	2.06250
# 04	1.87500	2.01562
# 05	1.93750	2.00391
# 06	1.96875	2.00098
# 07	1.98438	2.00024
# 08	1.99219	2.00006
# 09	1.99609	2.00002
# 10	1.99805	2.00000

# %%
def gradient_descent(func, grad_func, x0, learning_rate=0.01, MaxIter=10, verbose=True):
    paths = []
    for i in range(MaxIter):
        x1 = x0 - learning_rate * grad_func(x0)
        if verbose:
            print('{0:03d} : {1:4.3f}, {2:4.2E}'.format(i, x1, func(x1)))
        x0 = x1
        paths.append(x0)
    return(x0, func(x0), np.array(paths))

# %%
xopt, fopt, paths = gradient_descent(f, grad_f, 0.0, learning_rate=1.05, MaxIter=9)
plt.plot(x, y, 'k-')
plt.plot(2, 2, 'sk')
plt.plot(paths, f(paths), 'ko:')
for k, point in enumerate(paths):
  plt.text(point, f(point), '$x_{0}$'.format(k), verticalalignment='bottom')
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
# Out:
# 000 : 4.200, 6.84E+00
# 001 : -0.420, 7.86E+00
# 002 : 4.662, 9.09E+00
# 003 : -0.928, 1.06E+01
# 004 : 5.221, 1.24E+01
# 005 : -1.543, 1.46E+01
# 006 : 5.897, 1.72E+01
# 007 : -2.287, 2.04E+01
# 008 : 6.716, 2.42E+01

# %%
xopt, fopt, paths = gradient_descent(f, grad_f, 0.0, learning_rate=0.05, MaxIter=9)
plt.plot(x, y, 'k-')
plt.plot(2, 2, 'sk')
plt.plot(paths, f(paths), 'ko:')
for k, point in enumerate(paths):
  plt.text(point, f(point), '$x_{0}$'.format(k), verticalalignment='bottom')
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
# Out:
# 000 : 0.200, 5.24E+00
# 001 : 0.380, 4.62E+00
# 002 : 0.542, 4.13E+00
# 003 : 0.688, 3.72E+00
# 004 : 0.819, 3.39E+00
# 005 : 0.937, 3.13E+00
# 006 : 1.043, 2.92E+00
# 007 : 1.139, 2.74E+00
# 008 : 1.225, 2.60E+00

# %%
xopt, fopt, paths = gradient_descent(f, grad_f, 0.0, learning_rate=0.05, MaxIter=1000)
plt.plot(x, y, 'k-')
plt.plot(2, 2, 'sk')
plt.plot(paths, f(paths), 'ko:')
for k, point in enumerate(paths):
  plt.text(point, f(point), '$x_{0}$'.format(k), verticalalignment='bottom')
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
# Out:
# 000 : 0.200, 5.24E+00
# 001 : 0.380, 4.62E+00
# 002 : 0.542, 4.13E+00
# 003 : 0.688, 3.72E+00
# 004 : 0.819, 3.39E+00
# 005 : 0.937, 3.13E+00
# 006 : 1.043, 2.92E+00
# 007 : 1.139, 2.74E+00
# 008 : 1.225, 2.60E+00
# 009 : 1.303, 2.49E+00
# 010 : 1.372, 2.39E+00
# 011 : 1.435, 2.32E+00
# 012 : 1.492, 2.26E+00
# 013 : 1.542, 2.21E+00
# 014 : 1.588, 2.17E+00
# 015 : 1.629, 2.14E+00
# 016 : 1.666, 2.11E+00
# 017 : 1.700, 2.09E+00
# 018 : 1.730, 2.07E+00
# 019 : 1.757, 2.06E+00
# 020 : 1.781, 2.05E+00
# 021 : 1.803, 2.04E+00
# 022 : 1.823, 2.03E+00
# 023 : 1.840, 2.03E+00
# 024 : 1.856, 2.02E+00
# 025 : 1.871, 2.02E+00
# 026 : 1.884, 2.01E+00
# 027 : 1.895, 2.01E+00
# 028 : 1.906, 2.01E+00
# 029 : 1.915, 2.01E+00
# 030 : 1.924, 2.01E+00
# 031 : 1.931, 2.00E+00
# 032 : 1.938, 2.00E+00
# 033 : 1.944, 2.00E+00
# 034 : 1.950, 2.00E+00
# 035 : 1.955, 2.00E+00
# 036 : 1.959, 2.00E+00
# 037 : 1.964, 2.00E+00
# 038 : 1.967, 2.00E+00
# 039 : 1.970, 2.00E+00
# 040 : 1.973, 2.00E+00
# ...

# %%
import numpy as np
import matplotlib.pylab as plt
from matplotlib.colors import LogNorm
from mpl_toolkits.mplot3d import Axes3D

def contour(f, x, y, level = np.logspace(0, 5, 35)):
	ax.contour(x, y, f(x,y), levels=level, norm=LogNorm(), cmap='coolwarm')

	ax.set_xlabel('$x$')
	ax.set_ylabel('$y$')

	# ax.set_xlim((xmin, xmax))
	# ax.set_ylim((ymin, ymax))

	plt.show()

def contour_with_quiver(f, x, y, grad_x, grad_y, norm=LogNorm(), level = np.logspace(0, 5, 35),
	minima=None):
	dz_dx = grad_x(x,y)
	dz_dy = grad_y(x,y)

	fig, ax = plt.subplots()

	ax.contour(x, y, f(x,y), levels=level, norm=norm, cmap='coolwarm')
	if minima is not None:
		ax.plot(*minima, '*r', markersize=18)
	ax.quiver(x, y, -dz_dx, -dz_dy, alpha=.5)
	ax.set_xlabel('$x$')
	ax.set_ylabel('$y$')
	plt.axis('equal')

	# ax.set_xlim((xmin, xmax))
	# ax.set_ylim((ymin, ymax))

	plt.show()

def surf(f, x, y, norm=LogNorm(), minima=None):
	ax = plt.axes(projection='3d', elev=50, azim=-50)

	ax.plot_surface(x, y, f(x,y), norm=norm, rstride=1, cstride=1,
	                edgecolor='none', alpha=.8, cmap='coolwarm')

	if minima is not None:
		ax.plot(*minima, f(*minima), '*r', markersize=15)

	ax.set_xlabel('$x$')
	ax.set_ylabel('$y$')
	ax.set_zlabel('$z$')

	plt.show()

def contour_with_path(f, x, y, paths, norm=LogNorm(), level=np.logspace(0, 5, 35), minima=None):
	fig, ax = plt.subplots()

	ax.contour(x, y, f(x,y), levels=level, norm=norm, cmap='coolwarm')
	ax.quiver(paths[0,:-1], paths[1,:-1], paths[0,1:]-paths[0,:-1], paths[1,1:]-paths[1,:-1], scale_units='xy', angles='xy', scale=1, color='k')
	if minima is not None:
		ax.plot(*minima, 'r*', markersize=18)

	ax.set_xlabel('$x$')
	ax.set_ylabel('$y$')
	plt.axis('equal')

	# ax.set_xlim((xmin, xmax))
	# ax.set_ylim((ymin, ymax))

	plt.show()

# %%
f = lambda x, y: 3*(x-2)**2 + (y-2)**2

xmin, xmax, xstep = -8.0, 8.0, .25
ymin, ymax, ystep = -4.0, 4.0, .125
x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep), np.arange(ymin, ymax+ystep, ystep))

#from visualize import surf
minima_ = np.array([[2], [2]])
surf (f, x, y, minima=minima_)

# %%
grad_f_x = lambda x, y: 6*(x-2)
grad_f_y = lambda x, y: 2*(y-2)

xmin, xmax, xstep = -8.0, 8.0, .5
ymin, ymax, ystep = -4.0, 4.0, .25
x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep), np.arange(ymin, ymax+ystep, ystep))

contour_with_quiver(f, x, y, grad_f_x, grad_f_y)
# Out:
# <ipython-input-15-c70f592d6366>:24: UserWarning: Log scale: values of z <= 0 have been masked
#   ax.contour(x, y, f(x,y), levels=level, norm=norm, cmap='coolwarm')
